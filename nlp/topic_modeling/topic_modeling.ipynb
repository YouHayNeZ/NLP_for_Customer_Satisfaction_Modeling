# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from topic_modeling_LDA import *
from topic_modeling_setfit_absa import *
import os
import warnings
warnings.filterwarnings("ignore")
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../')))
from nlp.comments_preprocessing import *

# %%
# Load the CSV file from the constructed file path
data,comments = read_dataframes()

# %% [markdown]
# **Topic modeling with LDA**

# %%
# Copy the original comments DataFrame to avoid modifying the original data
comments_lda = comments.copy()

comments_lda = lda_topic_modeling(comments_lda, "cleaned_Comment", 5)

'''
if you want to change the csv file:
os.chdir("../../")
comments_lda.to_csv('data/processed/comments_lda.csv')
os.chdir("nlp/topic_modeling")
'''

# %% [markdown]
# **Topic modeling with setfit**

# %%
# Copy the original comments DataFrame to avoid modifying the original data
comments_setfit = comments.copy()
comments_setfit = comments_setfit.head(10)

# Apply the extract_aspects function to each row of the 'Comment' column
# for 10 comments, needed more than 15 min... so i just aborted it
comments_setfit[['Aspects', 'Labels']] = comments['Comment'].apply(lambda x: pd.Series(extract_aspects(x)))
